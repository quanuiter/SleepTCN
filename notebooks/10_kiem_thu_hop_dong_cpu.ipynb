# %% [markdown]
# # Kiem thu hop dong toan tuyen tren CPU
#
# Notebook nay chi xac minh du lieu, hinh dang tensor, mat na nhan va gradient truoc khi thue GPU. Ket qua loss khong phai ket qua danh gia mo hinh.

# %%
from pathlib import Path
import subprocess
import sys

workspace = Path.cwd()
if workspace.name == 'notebooks':
    workspace = workspace.parent
command = [sys.executable, str(workspace / 'scripts' / 'cpu_contract_smoke.py'), '--workspace', str(workspace)]
subprocess.run(command, check=True)
